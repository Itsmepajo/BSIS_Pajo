# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Itsmepajo/BSIS_Pajo/main/example.csv')

# %%
df.head()
# Out:
#    age   income  gender  purchased
# 0   32      NaN    male        1.0
# 1   23  12323.0  female        1.0
# 2   23   4423.0     NaN        0.0
# 3   44   1345.0  female        NaN
# 4   43  54523.0     NaN        1.0

# %%
print(df.tail())
# Out:
#    age   income  gender  purchased
# 1   23  12323.0  female        1.0
# 2   23   4423.0     NaN        0.0
# 3   44   1345.0  female        NaN
# 4   43  54523.0     NaN        1.0
# 5   12   2312.0  female        1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        6 non-null      int64
#  1   income     5 non-null      float64
#  2   gender     4 non-null      object
#  3   purchased  5 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 320.0+ bytes

# %%
print(df.describe())
# Out:
#              age        income  purchased
# count   6.000000      5.000000   5.000000
# mean   29.500000  14985.200000   0.800000
# std    12.565827  22519.713924   0.447214
# min    12.000000   1345.000000   0.000000
# 25%    23.000000   2312.000000   1.000000
# 50%    27.500000   4423.000000   1.000000
# 75%    40.250000  12323.000000   1.000000
# max    44.000000  54523.000000   1.000000

# %%
print(df.shape)
# Out:
# (6, 4)

# %%
print(df.columns)
# Out:
# Index(['age', 'income', 'gender', 'purchased'], dtype='object')

# %%
df_drop = df.drop('age', axis=1)

# %%
df_drop.head()
# Out:
#     income  gender  purchased
# 0      NaN    male        1.0
# 1  12323.0  female        1.0
# 2   4423.0     NaN        0.0
# 3   1345.0  female        NaN
# 4  54523.0     NaN        1.0

# %%
df_fillnq = df.fillna(0)

# %%
df_fillnq.head()
# Out:
#    age   income  gender  purchased
# 0   32      0.0    male        1.0
# 1   23  12323.0  female        1.0
# 2   23   4423.0       0        0.0
# 3   44   1345.0  female        0.0
# 4   43  54523.0       0        1.0

# %%
df_dropna = df.dropna()

# %%
df_dropna.head()
# Out:
#    age   income  gender  purchased
# 1   23  12323.0  female        1.0
# 5   12   2312.0  female        1.0

# %%
df = df.sort_values(by='age', ascending=True)

# %%
df.head()
# Out:
#    age   income  gender  purchased
# 5   12   2312.0  female        1.0
# 1   23  12323.0  female        1.0
# 2   23   4423.0     NaN        0.0
# 0   32      NaN    male        1.0
# 4   43  54523.0     NaN        1.0

# %%
df_grouped = df.groupby('gender').mean()

# %%
df_grouped.head()
# Out:
#               age       income  purchased
# gender
# female  26.333333  5326.666667        1.0
# male    32.000000          NaN        1.0

# %%
df_apply = df['gender'] = df['age'].apply(lambda x: x*2)

# %%
df_apply.head()
# Out:
# 5    24
# 1    46
# 2    46
# 0    64
# 4    86
# Name: age, dtype: int64

# %%
df1 = pd.DataFrame({'key':['age','gender',], 'values':[32,'male']})
df2 = pd.DataFrame({'key':['age','gender',], 'values':[23,'female']})
merged_df = pd.merge(df2, df2, on = 'key')

# %%
merged_df.head()
# Out:
#       key values_x values_y
# 0     age       23       23
# 1  gender   female   female

# %%
pivot_df = df.pivot_table(values = 'gender' , index = 'income', aggfunc = 'mean')

# %%
pivot_df.head()
# Out:
#          gender
# income
# 1345.0     88.0
# 2312.0     24.0
# 4423.0     46.0
# 12323.0    46.0
# 54523.0    86.0
